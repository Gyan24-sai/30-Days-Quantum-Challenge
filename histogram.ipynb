# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyan24-sai/30-Days-Quantum-Challenge/blob/main/histogram.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import qiskit
import qiskit_aer

print(qiskit.__version__)
print(qiskit_aer.__version__)
# Out:
# 2.4.2
# 0.17.2

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator
from qiskit.visualization import plot_histogram
import matplotlib.pyplot as plt

# Create simulator
simulator = AerSimulator()

# Create circuit
qc = QuantumCircuit(1, 1)

# Apply Hadamard gate
qc.h(0)

# Measure
qc.measure(0, 0)

# Run simulation
job = simulator.run(qc, shots=1000)
result = job.result()

# Get counts
counts = result.get_counts()

print("Counts:", counts)

# Plot histogram
fig = plot_histogram(counts)
plt.show()
# Out:
# Counts: {'0': 521, '1': 479}

# %%
fig = plot_histogram(counts)
display(fig)
