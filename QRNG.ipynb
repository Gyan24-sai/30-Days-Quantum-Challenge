# %% [markdown]
# <a href="https://colab.research.google.com/github/Gyan24-sai/30-Days-Quantum-Challenge/blob/main/QRNG.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from qiskit import QuantumCircuit
from qiskit_aer import AerSimulator

simulator = AerSimulator()

qc = QuantumCircuit(1,1)

qc.h(0)
qc.measure(0,0)

job = simulator.run(qc, shots=1000)
result = job.result()

counts = result.get_counts()

print("Quantum Random Numbers")
print(counts)
# Out:
# Quantum Random Numbers
# {'0': 508, '1': 492}
